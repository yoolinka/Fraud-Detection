# %% [markdown]
# # Client Level Features Columns
#
# Load `client_level_features.parquet` and print all column names.

# %%
import sys
from pathlib import Path

# Ensure project root is importable when notebook runs from /parquet
project_root = Path.cwd()
if project_root.name == "parquet":
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from config import load_data

_, client_data, _, _, _ = load_data()

print(f"Rows: {len(client_data)}")
print(f"Columns: {len(client_data.columns)}")
list(client_data.columns)
# Out:
# Rows: 287718
# Columns: 37
# ['num_of_trn',
#  'days_visits',
#  'num_of_waiters',
#  'num_of_places',
#  'gross_amount_mean',
#  'gross_amount_sum',
#  'gross_amount_max',
#  'bonuses_accum_sum',
#  'bonuses_used_sum',
#  'bonus_trn_count',
#  'first_last_trn_diff',
#  'first_second_trn_diff',
#  'first_third_trn_diff',
#  'time_between_trn_median',
#  'share_bonus_after_first',
#  'trn_per_day',
#  'share_bonus_trn',
#  'top_waiter_id',
#  'share_top_waiter',
#  'share_bonuses_used_top_waiter',
#  'top_place_id',
#  'share_top_places',
#  'is_fraud',
#  'num_of_trn_prcnt',
#  'days_visits_prcnt',
#  'gross_amount_mean_prcnt',
#  'gross_amount_sum_prcnt',
#  'bonuses_accum_sum_prcnt',
#  'bonuses_used_sum_prcnt',
#  'num_of_waiters_prcnt',
#  'gross_amount_max_prcnt',
#  'first_last_trn_diff_prcnt',
#  'first_second_trn_diff_prcnt',
#  'first_third_trn_diff_prcnt',
#  'time_between_trn_median_prcnt',
#  'trn_per_day_prcnt',
#  'num_of_places_prcnt']
