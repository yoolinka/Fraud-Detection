# %% [markdown]
# # Person-level (`person_id`) feature selection
#
# Pipeline (each step in its own code cell below), mirroring `A_tuning/features_selection.ipynb` but on **client-level** data from `config.load_data` (index = `person_id`). Anomaly models and hyperparameters match `models/fit_and_evaluate.py` / `models/models.py`.
#
# 1. **Variance filter** — drop near-constant numeric columns (variance below a small threshold).
# 2. **ANOVA** — keep features with statistically significant fraud vs non-fraud separation (`f_classif`), same filtering as the waiter–week notebook.
# 3. **Random forest importances** — `RandomForestClassifier.feature_importances_` on the scaled synthetic-fraud train setup (disjoint fraud *persons*, scaler fit on train non-fraud only).
# 4. **Correlation filter** — drop highly correlated features on non-fraud data, keeping the higher-MDI survivor (Step 3b).
# 5. **Permutation importance (`precision@50`)** — one code cell per anomaly model on the **filtered** feature set (Step 3c).
# 6. **Backward RFE** — each step **tries** features in **lowest RF MDI** order; a feature is removed only if **`precision@50` improves**, or **ties** and **`precision@100` does not decrease** (otherwise skip and try the next). Same candidate order for all models; metrics are model-specific (**Isolation Forest**, **OCSVM**, **LOF**).
#
# Run cells in order. The first code cell loads data and defines shared helpers.

# %%
"""Shared setup: load person-level (client) data, leakage-safe preprocessing, synthetic-fraud helpers (same design as waiter–week `features_selection.ipynb`)."""
import os
import sys
import warnings
from typing import Optional

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")

_project_root = os.path.abspath("..")
if _project_root not in sys.path:
    sys.path.insert(0, _project_root)

from models.scaling import scale_features, _auto_skewed_columns
from config import load_data

# --- Same defaults as gini / waiter feature selection (adapted for person grain) ---
N_SYNTHETIC_FRAUD = 6000
N_SYNTHETIC_FRAUD_TRAIN = int(N_SYNTHETIC_FRAUD * 0.8)
N_SYNTHETIC_FRAUD_TEST = int(N_SYNTHETIC_FRAUD * 0.2)
N_TRAIN_FRAUD_TYPES = 25
NOISE_SCALE = 0.2
RANDOM_STATE = 42
ACTIVITY_STATE = 1
DAYS_VISITS = 2
TEST_SIZE = 0.2
SKEW_ABS_THRESHOLD = 1.0

_, person_data, _, _ = load_data(
    activity_state=ACTIVITY_STATE,
    days_visits=DAYS_VISITS,
)
# Index is person_id (see `config.load_data`).
y_fraud = person_data["is_fraud"].astype(int).values
person_data = person_data.copy()
person_data["is_fraud"] = y_fraud.astype(int)

features_to_drop = [c for c in person_data.columns if c.startswith("num_of_fraud")]
person_data = person_data.drop(columns=features_to_drop)

# Un-imputed copy: matches `load_data` → `compare_models` (median impute only inside `scale_features`).
# Selection steps below use `person_data` with mean-fill for non-finite numerics.
person_data_raw = person_data.copy()

person_numeric_all = [
    c
    for c in person_data.select_dtypes(include=[np.number]).columns
    if c != "is_fraud"
]

num_cols = person_data.select_dtypes(include=[np.number]).columns
non_fraud_df = person_data[person_data["is_fraud"] == 0]
for col in num_cols:
    col_nf = non_fraud_df[col]
    finite = col_nf[np.isfinite(col_nf)]
    mean_val = float(finite.mean()) if len(finite) else 0.0
    if not np.isfinite(mean_val):
        mean_val = 0.0
    col_vals = person_data[col]
    person_data[col] = np.where(~np.isfinite(col_vals), mean_val, col_vals)

if int(y_fraud.sum()) == 0:
    raise ValueError("No known fraud persons in filtered client data; cannot run this pipeline.")

_RATE_BOUNDS_ATOL = 1e-8


def _column_values_in_unit_interval(series: pd.Series) -> bool:
    s = pd.to_numeric(series, errors="coerce").dropna()
    if s.empty:
        return False
    lo, hi = float(s.min()), float(s.max())
    return lo >= -_RATE_BOUNDS_ATOL and hi <= 1.0 + _RATE_BOUNDS_ATOL


def synthesize_fraud_only(
    fraud_source: pd.DataFrame,
    n_synthetic: int,
    noise_scale: float = 0.1,
    rate_noise_scale: Optional[float] = None,
    random_state: int = 42,
    id_label: Optional[str] = None,
) -> pd.DataFrame:
    if len(fraud_source) == 0:
        raise ValueError("fraud_source is empty; cannot synthesize fraud.")
    synthetic = fraud_source.sample(
        n=n_synthetic, replace=True, random_state=random_state
    ).copy()
    num_cols_local = synthetic.select_dtypes("number").columns.difference(
        ["is_fraud"], sort=False
    )
    if "person_id" in synthetic.columns:
        num_cols_local = num_cols_local.difference(["person_id"], sort=False)
    num_cols_local = list(num_cols_local)
    if rate_noise_scale is None:
        rate_noise_scale = noise_scale * 0.25
    col_std = np.array(
        [
            rate_noise_scale
            if _column_values_in_unit_interval(fraud_source[c])
            else noise_scale
            for c in num_cols_local
        ],
        dtype=float,
    )
    rng = np.random.default_rng(random_state)
    noise = rng.normal(0, 1, (len(synthetic), len(num_cols_local))) * col_std
    synthetic.loc[:, num_cols_local] = synthetic[num_cols_local].values * (1 + noise)
    synthetic["is_fraud"] = 1
    synthetic["synthetic"] = 1
    prefix = (
        f"__synthetic_fraud__{id_label}_{random_state}_"
        if id_label
        else f"__synthetic_fraud__{random_state}_"
    )
    synthetic.index = [f"{prefix}{i}" for i in range(len(synthetic))]
    synthetic.index.name = fraud_source.index.name
    return synthetic


def build_fraud_type_generalization_datasets(
    df: pd.DataFrame,
    *,
    n_train_fraud_types: int,
    n_synthetic_fraud_train: int,
    n_synthetic_fraud_test: int,
    noise_scale: float,
    test_size_non_fraud: float,
    random_state: int,
):
    fraud_mask = df["is_fraud"] == 1
    fraud_types = df.index[fraud_mask].unique().tolist()
    if len(fraud_types) < 2:
        raise ValueError(
            "Need at least 2 distinct fraud persons for disjoint train/test fraud pools."
        )
    rng = np.random.RandomState(random_state)
    order = list(fraud_types)
    rng.shuffle(order)
    n_take_train = min(int(n_train_fraud_types), len(order) - 1)
    n_take_train = max(1, n_take_train)
    train_type_set = set(order[:n_take_train])
    test_type_set = set(order[n_take_train:])

    fraud_train_pool = df.loc[fraud_mask & df.index.isin(train_type_set)]
    fraud_test_pool = df.loc[fraud_mask & df.index.isin(test_type_set)]

    non_fraud = df.loc[~fraud_mask]
    idx_nf_train, idx_nf_test = train_test_split(
        non_fraud.index,
        test_size=test_size_non_fraud,
        random_state=random_state,
    )
    nf_train = df.loc[idx_nf_train].copy()
    nf_test = df.loc[idx_nf_test].copy()
    nf_train["synthetic"] = 0
    nf_test["synthetic"] = 0

    syn_train = synthesize_fraud_only(
        fraud_train_pool,
        n_synthetic=n_synthetic_fraud_train,
        noise_scale=noise_scale,
        random_state=random_state,
        id_label="train_types",
    )
    syn_test = synthesize_fraud_only(
        fraud_test_pool,
        n_synthetic=n_synthetic_fraud_test,
        noise_scale=noise_scale,
        random_state=random_state + 1,
        id_label="test_types_only",
    )
    train_df = pd.concat([nf_train, syn_train])
    test_df = pd.concat([nf_test, syn_test])
    full_df = pd.concat([train_df, test_df])
    meta = {
        "n_fraud_types": len(fraud_types),
        "n_train_fraud_types": len(train_type_set),
        "n_test_fraud_types": len(test_type_set),
    }
    return train_df, test_df, full_df, meta


def build_scaled_train_test(feature_list: list[str]):
    """Scaled X_train/X_test and y for a given feature list (gini-style)."""
    train_df, test_df, synthetic, split_meta = build_fraud_type_generalization_datasets(
        person_data,
        n_train_fraud_types=N_TRAIN_FRAUD_TYPES,
        n_synthetic_fraud_train=N_SYNTHETIC_FRAUD_TRAIN,
        n_synthetic_fraud_test=N_SYNTHETIC_FRAUD_TEST,
        noise_scale=NOISE_SCALE,
        test_size_non_fraud=TEST_SIZE,
        random_state=RANDOM_STATE,
    )
    idx_train = train_df.index
    idx_test = test_df.index
    train_non_fraud = synthetic.loc[idx_train]
    train_non_fraud = train_non_fraud[train_non_fraud["is_fraud"] == 0]
    if len(train_non_fraud) == 0:
        raise ValueError("Train split has no non-fraud rows.")
    impute_ref = train_non_fraud
    skewed = _auto_skewed_columns(synthetic, feature_list, SKEW_ABS_THRESHOLD)
    _, X_scaled = scale_features(
        data=synthetic,
        features=feature_list,
        scaler_type="standard",
        skew_abs_threshold=SKEW_ABS_THRESHOLD,
        fit_data=train_non_fraud,
        impute_reference=impute_ref,
    )
    X_train = X_scaled.loc[idx_train].values.astype(np.float64)
    X_test = X_scaled.loc[idx_test].values.astype(np.float64)
    y_train = synthetic.loc[idx_train, "is_fraud"].astype(int).values
    y_test = synthetic.loc[idx_test, "is_fraud"].astype(int).values
    return X_train, X_test, y_train, y_test, skewed, split_meta


print(
    f"Loaded person (client) rows={len(person_data)}, fraud={int(y_fraud.sum())}, "
    f"numeric feature candidates={len(person_numeric_all)}"
)
# Out:
# Loaded person (client) rows=197763, fraud=43, numeric feature candidates=34

# %% [markdown]
# ## Step 1 — variance filter
#
# Drop numeric columns whose variance (after finite-value handling in setup) is below `MIN_VARIANCE`.

# %%
MIN_VARIANCE = 1e-8

X_var = person_data[person_numeric_all].astype(float)
col_var = X_var.var(axis=0, skipna=True)
features_after_variance = col_var[col_var >= MIN_VARIANCE].index.tolist()
n_dropped = len(person_numeric_all) - len(features_after_variance)
print(
    f"Step 1 (variance ≥ {MIN_VARIANCE:g}): kept {len(features_after_variance)} / {len(person_numeric_all)} features; dropped {n_dropped} low-variance columns."
)
# Out:
# Step 1 (variance ≥ 1e-08): kept 34 / 34 features; dropped 0 low-variance columns.

# %% [markdown]
# ## Step 2 — ANOVA (`f_classif`)
#
# Same filtering as `avona.ipynb`: rows must be finite on all candidate columns; drop constant columns; significance column `significant_0.05` (see waiter–week notebook).

# %%
from sklearn.feature_selection import f_classif

y = person_data["is_fraud"].astype(int)
X = person_data[features_after_variance].replace([np.inf, -np.inf], np.nan)
complete = np.isfinite(X.to_numpy(dtype=float)).all(axis=1)
X_use = X.loc[complete]
y_use = y.loc[complete]

n_fraud = int(y_use.sum())
n_ok = int((y_use == 0).sum())
print(f"Rows for ANOVA (all finite): {len(X_use)} (fraud={n_fraud}, non-fraud={n_ok})")

if n_fraud < 2 or n_ok < 2:
    raise ValueError("Need at least 2 samples in each class for ANOVA.")

std = X_use.std()
numeric_cols_fit = [c for c in features_after_variance if std[c] > 0 and np.isfinite(std[c])]
if len(numeric_cols_fit) < len(features_after_variance):
    print(f"Dropped {len(features_after_variance) - len(numeric_cols_fit)} constant column(s) before ANOVA.")

F_scores, p_values = f_classif(X_use[numeric_cols_fit], y_use)
means_fraud = X_use.loc[y_use == 1, numeric_cols_fit].mean()
means_nonfraud = X_use.loc[y_use == 0, numeric_cols_fit].mean()

anova_results = (
    pd.DataFrame(
        {
            "feature": numeric_cols_fit,
            "F_score": F_scores,
            "p_value": p_values,
            "mean_fraud": means_fraud.values,
            "mean_nonfraud": means_nonfraud.values,
        }
    )
    .sort_values("p_value", kind="mergesort")
    .reset_index(drop=True)
)
anova_results["significant_0.05"] = anova_results["p_value"] < 0.05
anova_results["significant_bonferroni_0.05"] = anova_results["p_value"] < (
    0.05 / len(numeric_cols_fit)
)

features_after_anova = anova_results.loc[
    anova_results["significant_0.05"], "feature"
].tolist()
print(f"Step 2 (Bonferroni): kept {len(features_after_anova)} significant features.")

display(anova_results.head(40))
# Out:
# Rows for ANOVA (all finite): 197763 (fraud=43, non-fraud=197720)
# Step 2 (Bonferroni): kept 31 significant features.
#                           feature     F_score        p_value    mean_fraud  \
# 0               bonuses_accum_sum  667.843836  5.170812e-147   2899.720930
# 1                gross_amount_sum  624.057825  1.604158e-137  31175.270698
# 2                share_top_waiter  437.890222   3.973880e-97      0.807342
# 3                bonuses_used_sum  384.052089   1.968173e-85   2405.255814
# 4               gross_amount_mean  174.844563   6.731555e-40   1243.957806
# 5                gross_amount_max  123.710392   9.941646e-29   3307.855814
# 6         bonuses_accum_sum_prcnt  113.325572   1.861494e-26      0.968459
# 7          gross_amount_sum_prcnt  107.573407   3.383298e-25      0.956422
# 8          bonuses_used_sum_prcnt   96.663785   8.315448e-23      0.931961
# 9                share_top_places   94.537607   2.432694e-22      0.942017
# 10  share_bonuses_used_top_waiter   77.498485   1.338624e-18      0.643696
# 11         gross_amount_max_prcnt   74.277886   6.834701e-18      0.879298
# 12        gross_amount_mean_prcnt   62.359249   2.876392e-15      0.847548
# 13               num_of_trn_prcnt   57.697018   3.070997e-14      0.833425
# 14              days_visits_prcnt   55.974549   7.371693e-14      0.825326
# 15           num_of_waiters_prcnt   45.254143   1.735222e-11      0.205277
# 16                     num_of_trn   39.370982   3.511885e-10     32.837209
# 17            num_of_places_prcnt   39.287559   3.665148e-10      0.226738
# 18            first_last_trn_diff   29.668607   5.131909e-08   3616.183456
# 19      first_last_trn_diff_prcnt   29.609731   5.290151e-08      0.260497
# 20                    days_visits   28.936367   7.488000e-08     19.860465
# 21                  num_of_places   25.764902   3.859863e-07      2.000000
# 22     first_third_trn_diff_prcnt   23.183656   1.473520e-06      0.288071
# 23                    trn_per_day   21.316387   3.896329e-06      1.938417
# 24  time_between_trn_median_prcnt   20.496217   5.978400e-06      0.300731
# 25           first_third_trn_diff   17.142208   3.469729e-05    275.887397
# 26                bonus_trn_count   16.079395   6.076364e-05      8.534884
# 27                 num_of_waiters   15.262810   9.357125e-05      3.906977
# 28        time_between_trn_median   12.041453   5.204149e-04     67.059154
# 29          first_second_trn_diff    9.297687   2.294737e-03    114.866925
# 30    first_second_trn_diff_prcnt    5.736068   1.662088e-02      0.394581
# 31                share_bonus_trn    0.443884   5.052545e-01      0.312166
# 32              trn_per_day_prcnt    0.439020   5.075965e-01      0.471081
# 33        share_bonus_after_first    0.015670   9.003820e-01      0.330656
#
#     mean_nonfraud  significant_0.05  significant_bonferroni_0.05
# 0      430.145924              True                         True
# 1     5046.151817              True                         True
# 2        0.282629              True                         True
# 3      294.798882              True                         True
# 4      474.679335              True                         True
# 5     1252.372128              True                         True
# 6        0.499901              True                         True
# 7        0.499903              True                         True
# 8        0.499909              True                         True
# 9        0.554727              True                         True
# 10       0.251495              True                         True
# 11       0.499920              True                         True
# 12       0.499927              True                         True
# 13       0.499930              True                         True
# 14       0.499932              True                         True
# 15       0.500067              True                         True
# 16      12.755533              True                         True
# 17       0.500062              True                         True
# 18    7606.255497              True                         True
# 19       0.500055              True                         True
# 20       8.792909              True                         True
# 21       4.187887              True                         True
# 22       0.500049              True                         True
# 23       1.502805              True                         True
# 24       0.500046              True                         True
# 25    2119.737279              True                         True
# 26       3.767019              True                         True
# 27       8.258128              True                         True
# 28     660.255933              True                         True
# 29    1034.735320              True                        False
# 30       0.500025              True                        False
# 31       0.291715             False                        False
# 32       0.500009             False                        False
# 33       0.335210             False                        False

# %% [markdown]
# ## Step 3 — Random Forest feature importances
#
# Same training design as `gini_features_importance.ipynb`: disjoint synthetic fraud pools, `scale_features` fit on train non-fraud only. Importances are MDI on the train matrix.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

X_train, X_test, y_train, y_test, skewed_cols, split_meta = build_scaled_train_test(
    features_after_anova
)
print(
    f"Step 3: train shape {X_train.shape}, test shape {X_test.shape}; "
    f"log1p cols={len(skewed_cols)}; fraud persons train/test: "
    f"{split_meta['n_train_fraud_types']}/{split_meta['n_test_fraud_types']}"
)

rf = RandomForestClassifier(
    n_estimators=200,
    random_state=RANDOM_STATE,
    class_weight="balanced",
    n_jobs=-1,
)
rf.fit(X_train, y_train)

y_pred_test = rf.predict(X_test)
cm_test = confusion_matrix(y_test, y_pred_test, labels=[0, 1])
cm_test_df = pd.DataFrame(
    cm_test,
    index=["actual 0 (non-fraud)", "actual 1 (fraud)"],
    columns=["predicted 0", "predicted 1"],
)
print("Step 3: confusion matrix — test set (rows=actual, columns=predicted)")
display(cm_test_df)

rf_importance = (
    pd.DataFrame(
        {"feature": features_after_anova, "importance": rf.feature_importances_}
    )
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)
print("Step 3: RandomForest feature_importances_ (train fit, MDI).")
display(rf_importance)

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, max(3, 0.35 * len(rf_importance))))
top_n = min(40, len(rf_importance))
plot_df = rf_importance.head(top_n).iloc[::-1]
ax.barh(plot_df["feature"], plot_df["importance"], color="steelblue")
ax.set_xlabel("Feature importance")
ax.set_title(f"Random forest importances (top {top_n} of {len(rf_importance)})")
plt.tight_layout()
plt.show()
# Out:
# Step 3: train shape (162976, 31), test shape (40744, 31); log1p cols=16; fraud persons train/test: 25/18
# Step 3: confusion matrix — test set (rows=actual, columns=predicted)
#                       predicted 0  predicted 1
# actual 0 (non-fraud)        39541            3
# actual 1 (fraud)              561          639
# Step 3: RandomForest feature_importances_ (train fit, MDI).
#                           feature  importance
# 0                share_top_waiter    0.160052
# 1               bonuses_accum_sum    0.128125
# 2         bonuses_accum_sum_prcnt    0.109461
# 3                bonuses_used_sum    0.079568
# 4                gross_amount_sum    0.071993
# 5          gross_amount_sum_prcnt    0.059484
# 6                share_top_places    0.057851
# 7          bonuses_used_sum_prcnt    0.041871
# 8          gross_amount_max_prcnt    0.034019
# 9   share_bonuses_used_top_waiter    0.031953
# 10                 num_of_waiters    0.030451
# 11               num_of_trn_prcnt    0.023817
# 12           num_of_waiters_prcnt    0.022177
# 13      first_last_trn_diff_prcnt    0.017172
# 14                     num_of_trn    0.012046
# 15            num_of_places_prcnt    0.011904
# 16  time_between_trn_median_prcnt    0.011177
# 17               gross_amount_max    0.010681
# 18              days_visits_prcnt    0.010211
# 19          first_second_trn_diff    0.009215
# 20                  num_of_places    0.008953
# 21    first_second_trn_diff_prcnt    0.008549
# 22     first_third_trn_diff_prcnt    0.008506
# 23        gross_amount_mean_prcnt    0.007402
# 24        time_between_trn_median    0.006510
# 25                    trn_per_day    0.005772
# 26                    days_visits    0.005453
# 27            first_last_trn_diff    0.005231
# 28           first_third_trn_diff    0.004798
# 29              gross_amount_mean    0.003318
# 30                bonus_trn_count    0.002278

# %% [markdown]
# ## Step 3b — Correlation filter (after Random Forest)
#
# Using **non-fraud** rows in **`person_data_raw`**, compute absolute Pearson correlations between ANOVA features. Walk features in **descending RF MDI** (`rf_importance`): keep a feature only if its |corr| with **every already kept** feature is **strictly below** `CORR_THRESHOLD`. When two features are highly correlated, the one with **lower** forest importance is skipped.
#
# Output list: **`features_after_correlation`** — used for **Step 3c permutation importance** only (RFE / Step 4 still follows its own pool unless you change it).

# %%
CORR_THRESHOLD = 0.85

_imp_order = rf_importance.sort_values("importance", ascending=False)["feature"].tolist()
_nf = person_data_raw.loc[~person_data_raw["is_fraud"].astype(bool), _imp_order].copy()
_nf = _nf.replace([np.inf, -np.inf], np.nan).fillna(_nf.median(numeric_only=True)).fillna(0)
C = _nf.corr().abs()

kept = []
dropped_pairs = []
for f in _imp_order:
    conflict = None
    for s in kept:
        v = C.loc[f, s]
        if pd.notna(v) and float(v) >= CORR_THRESHOLD:
            conflict = s
            break
    if conflict is None:
        kept.append(f)
    else:
        dropped_pairs.append((f, conflict, float(C.loc[f, conflict])))

features_after_correlation = kept
print(
    f"Step 3b: |corr| < {CORR_THRESHOLD} vs kept set; "
    f"kept {len(features_after_correlation)} / {len(_imp_order)} features (non-fraud n={len(_nf)})."
)
if dropped_pairs:
    display(
        pd.DataFrame(
            dropped_pairs,
            columns=["dropped_lower_priority", "kept_correlated_partner", "abs_corr"],
        )
    )
# Out:
# Step 3b: |corr| < 0.85 vs kept set; kept 24 / 31 features (non-fraud n=197720).
#    dropped_lower_priority    kept_correlated_partner  abs_corr
# 0        gross_amount_sum          bonuses_accum_sum  0.918529
# 1  gross_amount_sum_prcnt    bonuses_accum_sum_prcnt  0.951697
# 2    num_of_waiters_prcnt           num_of_trn_prcnt  0.872913
# 3       days_visits_prcnt           num_of_trn_prcnt  0.859321
# 4           num_of_places        num_of_places_prcnt  0.915593
# 5             days_visits                 num_of_trn  0.916389
# 6     first_last_trn_diff  first_last_trn_diff_prcnt  0.997851

# %% [markdown]
# ## Step 3c — Permutation importance (`precision@50`)
#
# After **Step 3b (correlation filter)**, score how much each surviving column matters for **top-50 precision** on the anomaly ranking.
#
# **Setup (same as later RFE / `compare_models`):** full **`person_data_raw`** cohort (no notebook mean-imputation; same as `models.compare_models`), `scale_features` with standard scaling and `skew_abs_threshold=SKEW_ABS_THRESHOLD`, scaler fit on **non-fraud** only. The anomaly model is fit on scaled non-fraud rows; scores are computed on **all** rows.
#
# **Feature list:** `features_after_correlation` from Step 3b (RF-ranked, redundancy removed).
#
# **Permutation:** for each feature, that column of **`X_eval` only** is shuffled `PERM_N_REPEATS` times (fit unchanged). **Importance** = baseline `precision@50` − permuted `precision@50` (mean ± std over repeats). Larger mean ⇒ more impact on the metric.
#
# Hyperparameters match `models/fit_and_evaluate.py` / Step 4a (IF `n_estimators=200`, OCSVM `nu=0.0005` + 4k subsample with `default_rng(42)`, LOF `n_neighbors=5`, `novelty=True`).
#
# Run **Steps 3 → 3b** first, then **one code cell per model** below (each cell is self-contained).

# %%
"""Step 3c — Isolation Forest: permutation importance for precision@50 (features = `features_after_correlation`)."""
from sklearn.ensemble import IsolationForest

from models.fit_and_evaluate import _top_k_precision

PERM_N_REPEATS = 5

person_perm = person_data_raw.copy()
y_perm = person_perm["is_fraud"].astype(int).values
train_perm = person_perm.loc[~person_perm["is_fraud"].astype(bool).values]
feat_perm = list(features_after_correlation)

X_fit_df, X_eval_df = scale_features(
    data=person_perm,
    features=feat_perm,
    scaler_type="standard",
    skew_abs_threshold=SKEW_ABS_THRESHOLD,
    fit_data=train_perm,
)
X_fit_p = X_fit_df.values.astype(np.float64)
X_eval_p = X_eval_df.values.astype(np.float64)


def _precision_at_50(scores: np.ndarray) -> float:
    return float(_top_k_precision(scores, y_perm, [50])["precision@50"])


iso = IsolationForest(
    n_estimators=200,
    contamination=0.0005,
    max_samples=1.0,
    random_state=RANDOM_STATE,
    n_jobs=-1,
)
iso.fit(X_fit_p)
scores_base = -iso.score_samples(X_eval_p)
baseline = _precision_at_50(scores_base)

rows = []
for j, name in enumerate(feat_perm):
    deltas = []
    for r in range(PERM_N_REPEATS):
        rng = np.random.default_rng(RANDOM_STATE + r * 1_000_003 + j)
        X_perm = X_eval_p.copy()
        X_perm[:, j] = rng.permutation(X_perm[:, j])
        scores_j = -iso.score_samples(X_perm)
        deltas.append(baseline - _precision_at_50(scores_j))
    rows.append(
        {
            "feature": name,
            "importance_mean": float(np.mean(deltas)),
            "importance_std": float(np.std(deltas, ddof=0)),
        }
    )

perm_importance_iso = (
    pd.DataFrame(rows)
    .assign(baseline_precision_at_50=baseline)
    .sort_values("importance_mean", ascending=False)
    .reset_index(drop=True)
)
print(
    f"Isolation Forest — baseline precision@50={baseline:.4f} | "
    f"n_features={len(feat_perm)} | perm_repeats={PERM_N_REPEATS}"
)
display(perm_importance_iso)
# Out:
# Isolation Forest — baseline precision@100=0.1500 | n_features=24 | perm_repeats=5
#                           feature  importance_mean  importance_std  \
# 0                share_top_waiter            0.100        0.006325
# 1                  num_of_waiters            0.090        0.000000
# 2         gross_amount_mean_prcnt            0.080        0.010954
# 3                num_of_trn_prcnt            0.072        0.011662
# 4          bonuses_used_sum_prcnt            0.070        0.016733
# 5         bonuses_accum_sum_prcnt            0.068        0.009798
# 6       first_last_trn_diff_prcnt            0.066        0.004899
# 7                share_top_places            0.064        0.008000
# 8   share_bonuses_used_top_waiter            0.064        0.018547
# 9                bonuses_used_sum            0.058        0.007483
# 10                    trn_per_day            0.058        0.011662
# 11              bonuses_accum_sum            0.048        0.007483
# 12            num_of_places_prcnt            0.044        0.020591
# 13        time_between_trn_median            0.040        0.010954
# 14         gross_amount_max_prcnt            0.040        0.016733
# 15                bonus_trn_count            0.038        0.014697
# 16           first_third_trn_diff            0.034        0.014967
# 17  time_between_trn_median_prcnt            0.030        0.008944
# 18     first_third_trn_diff_prcnt            0.026        0.020591
# 19          first_second_trn_diff            0.022        0.013266
# 20    first_second_trn_diff_prcnt            0.008        0.017205
# 21              gross_amount_mean           -0.002        0.004000
# 22                     num_of_trn           -0.004        0.004899
# 23               gross_amount_max           -0.020        0.006325
#
#     baseline_precision_at_100
# 0                        0.15
# 1                        0.15
# 2                        0.15
# 3                        0.15
# 4                        0.15
# 5                        0.15
# 6                        0.15
# 7                        0.15
# 8                        0.15
# 9                        0.15
# 10                       0.15
# 11                       0.15
# 12                       0.15
# 13                       0.15
# 14                       0.15
# 15                       0.15
# 16                       0.15
# 17                       0.15
# 18                       0.15
# 19                       0.15
# 20                       0.15
# 21                       0.15
# 22                       0.15
# 23                       0.15

# %%
"""Step 3c — One-Class SVM: permutation importance for precision@50 (features = `features_after_correlation`)."""
from sklearn.svm import OneClassSVM

from models.fit_and_evaluate import _top_k_precision

PERM_N_REPEATS = 7
MAX_OCSVM_TRAIN = 4000

person_perm = person_data_raw.copy()
y_perm = person_perm["is_fraud"].astype(int).values
train_perm = person_perm.loc[~person_perm["is_fraud"].astype(bool).values]
feat_perm = list(features_after_correlation)

X_fit_df, X_eval_df = scale_features(
    data=person_perm,
    features=feat_perm,
    scaler_type="standard",
    skew_abs_threshold=SKEW_ABS_THRESHOLD,
    fit_data=train_perm,
)
X_fit_p = X_fit_df.values.astype(np.float64)
X_eval_p = X_eval_df.values.astype(np.float64)


def _precision_at_50(scores: np.ndarray) -> float:
    return float(_top_k_precision(scores, y_perm, [50])["precision@50"])


n_fit = len(X_fit_p)
if n_fit > MAX_OCSVM_TRAIN:
    rng_fit = np.random.default_rng(42)
    idx = rng_fit.choice(n_fit, size=MAX_OCSVM_TRAIN, replace=False)
    X_fit_s = X_fit_p[idx]
else:
    X_fit_s = X_fit_p
ocsvm = OneClassSVM(kernel="rbf", nu=0.0005, gamma="scale")
ocsvm.fit(X_fit_s)

scores_base = -ocsvm.decision_function(X_eval_p)
baseline = _precision_at_50(scores_base)

rows = []
for j, name in enumerate(feat_perm):
    deltas = []
    for r in range(PERM_N_REPEATS):
        rng = np.random.default_rng(RANDOM_STATE + r * 1_000_003 + j)
        X_perm = X_eval_p.copy()
        X_perm[:, j] = rng.permutation(X_perm[:, j])
        scores_j = -ocsvm.decision_function(X_perm)
        deltas.append(baseline - _precision_at_50(scores_j))
    rows.append(
        {
            "feature": name,
            "importance_mean": float(np.mean(deltas)),
            "importance_std": float(np.std(deltas, ddof=0)),
        }
    )

perm_importance_ocsvm = (
    pd.DataFrame(rows)
    .assign(baseline_precision_at_50=baseline)
    .sort_values("importance_mean", ascending=False)
    .reset_index(drop=True)
)
print(
    f"One-Class SVM — baseline precision@50={baseline:.4f} | "
    f"n_features={len(feat_perm)} | perm_repeats={PERM_N_REPEATS}"
)
display(perm_importance_ocsvm)
# Out:
# One-Class SVM — baseline precision@50=0.1200 | n_features=24 | perm_repeats=7
#                           feature  importance_mean  importance_std  \
# 0                     trn_per_day         0.120000        0.000000
# 1               bonuses_accum_sum         0.097143        0.012778
# 2                  num_of_waiters         0.088571        0.014569
# 3                      num_of_trn         0.057143        0.006999
# 4                 bonus_trn_count         0.054286        0.009035
# 5                share_top_waiter         0.051429        0.009897
# 6               gross_amount_mean         0.037143        0.006999
# 7             num_of_places_prcnt         0.028571        0.018070
# 8         time_between_trn_median         0.028571        0.009897
# 9                gross_amount_max         0.025714        0.017613
# 10        bonuses_accum_sum_prcnt         0.025714        0.013997
# 11               num_of_trn_prcnt         0.022857        0.012778
# 12        gross_amount_mean_prcnt         0.022857        0.006999
# 13         gross_amount_max_prcnt         0.020000        0.015119
# 14      first_last_trn_diff_prcnt         0.020000        0.015119
# 15         bonuses_used_sum_prcnt         0.020000        0.010690
# 16               bonuses_used_sum         0.017143        0.012778
# 17  time_between_trn_median_prcnt         0.014286        0.013997
# 18  share_bonuses_used_top_waiter         0.011429        0.009897
# 19    first_second_trn_diff_prcnt         0.011429        0.009897
# 20          first_second_trn_diff         0.008571        0.009897
# 21     first_third_trn_diff_prcnt         0.005714        0.009035
# 22           first_third_trn_diff         0.005714        0.013997
# 23               share_top_places        -0.002857        0.016660
#
#     baseline_precision_at_50
# 0                       0.12
# 1                       0.12
# 2                       0.12
# 3                       0.12
# 4                       0.12
# 5                       0.12
# 6                       0.12
# 7                       0.12
# 8                       0.12
# 9                       0.12
# 10                      0.12
# 11                      0.12
# 12                      0.12
# 13                      0.12
# 14                      0.12
# 15                      0.12
# 16                      0.12
# 17                      0.12
# 18                      0.12
# 19                      0.12
# 20                      0.12
# 21                      0.12
# 22                      0.12
# 23                      0.12

# %%
"""Step 3c — LOF (novelty): permutation importance for precision@50 (features = `features_after_correlation`)."""
from sklearn.neighbors import LocalOutlierFactor

from models.fit_and_evaluate import _top_k_precision

PERM_N_REPEATS = 5

person_perm = person_data_raw.copy()
y_perm = person_perm["is_fraud"].astype(int).values
train_perm = person_perm.loc[~person_perm["is_fraud"].astype(bool).values]
feat_perm = list(features_after_correlation)

X_fit_df, X_eval_df = scale_features(
    data=person_perm,
    features=feat_perm,
    scaler_type="standard",
    skew_abs_threshold=SKEW_ABS_THRESHOLD,
    fit_data=train_perm,
)
X_fit_p = X_fit_df.values.astype(np.float64)
X_eval_p = X_eval_df.values.astype(np.float64)


def _precision_at_50(scores: np.ndarray) -> float:
    return float(_top_k_precision(scores, y_perm, [50])["precision@50"])


lof = LocalOutlierFactor(
    n_neighbors=5,
    contamination=0.01,
    metric="minkowski",
    p=2,
    novelty=True,
)
lof.fit(X_fit_p)
scores_base = -lof.score_samples(X_eval_p)
baseline = _precision_at_50(scores_base)

rows = []
for j, name in enumerate(feat_perm):
    deltas = []
    for r in range(PERM_N_REPEATS):
        rng = np.random.default_rng(RANDOM_STATE + r * 1_000_003 + j)
        X_perm = X_eval_p.copy()
        X_perm[:, j] = rng.permutation(X_perm[:, j])
        scores_j = -lof.score_samples(X_perm)
        deltas.append(baseline - _precision_at_50(scores_j))
    rows.append(
        {
            "feature": name,
            "importance_mean": float(np.mean(deltas)),
            "importance_std": float(np.std(deltas, ddof=0)),
        }
    )

perm_importance_lof = (
    pd.DataFrame(rows)
    .assign(baseline_precision_at_50=baseline)
    .sort_values("importance_mean", ascending=False)
    .reset_index(drop=True)
)
print(
    f"LOF — baseline precision@50={baseline:.4f} | "
    f"n_features={len(feat_perm)} | perm_repeats={PERM_N_REPEATS}"
)
display(perm_importance_lof)

# %% [markdown]
# ## Step 4 — Backward recursive feature elimination (anomaly models)
#
# Scale with `scale_features` (fit on **non-fraud** only), fit the anomaly model on scaled non-fraud, score **all** rows. **Each step** tries removing the next **lowest-importance** survivor (RF MDI or Step 3c permutation, via `RFE_IMPORTANCE_SOURCE` / `importance_source=`). Whether a trial removal is allowed is controlled by **`RFE_REMOVAL_GUARD`** in Step 4a or `backward_rfe_anomaly(..., removal_guard=...)`: default **`p50_primary`** matches the original rule ( **`precision@50`** must not drop; on a tie at @50, **`precision@100`** must not drop). Use **`p50_only`** or **`p100_only`** to guard only that metric; use **`both`** to require neither metric to drop. If no candidate passes, RFE **stops early**. Target pool size is **`N_FEATURES_RFE_TARGET`**. Metrics are model-specific (IF / OCSVM / LOF).
#
#
# **Removal order:** set `RFE_IMPORTANCE_SOURCE` in Step 4a to `"rf"` (Random Forest MDI, Step 3) or `"perm_iso"` / `"perm_ocsvm"` / `"perm_lof"` (Step 3c permutation `importance_mean`). You can also pass `importance_source=` on a single `backward_rfe_anomaly(...)` call to override for that run only. The feature **set** is always the ANOVA survivors; only the **priority** for trying removals changes.
#
# **Feature pool:** the ANOVA survivor set (same columns as Step 3 RF); their **ordering** for RFE comes from `RFE_POOL_ORDERED` in Step 4a (RF MDI or Step 3c permutation table). Run **Step 4a**, then one cell per model.
#
# **Evaluation cohort:** Step 4a uses **`person_data_raw`** — same rows and missing-value handling as `models.compare_models`’s `client_data` (`scale_features` medians only). The mean-imputed **`person_data`** is still used for variance / ANOVA / RF. ANOVA’s finite-row subset (`X_use`) does not restrict scoring. With the same `activity_state`, `days_visits`, and feature list (as in `config.FEATURES`), **`precision@50`** and **`precision@100`** should match `fit_and_evaluate` / `compare_models`.

# %%
"""Step 4a — shared prep + backward RFE driver (configurable removal guard).

Anomaly evaluation matches `models.compare_models` → `scale_features` + `fit_and_evaluate`:
full person cohort from `load_data` (all rows in `person_data`), scaler fit on non-fraud only,
OCSVM train subsample uses `np.random.default_rng(42)` like `fit_and_evaluate` (not RandomState).

RFE removal tries **low-importance** features first. **Performance guard** is set by **`RFE_REMOVAL_GUARD`**
or `backward_rfe_anomaly(..., removal_guard=...)`: **`p50_primary`** (default) keeps precision@50 from
dropping and, on a tie at @50, requires precision@100 not to drop; **`p50_only`** / **`p100_only`** reject
a removal only when that single metric would drop; **`both`** require neither metric to drop.

Importance comes from **`RFE_IMPORTANCE_SOURCE`**: Random Forest MDI (Step 3) or permutation
**`importance_mean`** from Step 3c (`perm_iso` / `perm_ocsvm` / `perm_lof`).
Override per call with `backward_rfe_anomaly(..., importance_source="perm_ocsvm")`.
"""
from typing import Literal, Optional

from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM

from models.fit_and_evaluate import _top_k_precision

try:
    from IPython.display import display
except ImportError:
    display = print

K_LIST = [50, 100]
MAX_OCSVM_TRAIN = 4000
_RFE_METRIC_EPS = 1e-12

# Removal-priority source: "rf" | "perm_iso" | "perm_ocsvm" | "perm_lof"
RFE_IMPORTANCE_SOURCE = "rf"

RFERemovalGuard = Literal["p50_primary", "p50_only", "p100_only", "both"]
# Default removal rule; override per call with backward_rfe_anomaly(..., removal_guard=...).
RFE_REMOVAL_GUARD: RFERemovalGuard = "p50_primary"


def build_rfe_pool_from_source(
    source: str,
) -> tuple[list[str], dict[str, float]]:
    """(pool ordered by descending importance, map feature -> importance score)."""
    s = str(source).strip().lower()
    if s == "rf":
        pool = rf_importance["feature"].tolist()
        imp = rf_importance.set_index("feature")["importance"].astype(float).to_dict()
        return pool, imp
    if s == "perm_iso":
        try:
            df = perm_importance_iso
        except NameError as e:
            raise RuntimeError(
                "Run Step 3c Isolation Forest permutation importance first (defines `perm_importance_iso`)."
            ) from e
        col = "importance_mean"
    elif s == "perm_ocsvm":
        try:
            df = perm_importance_ocsvm
        except NameError as e:
            raise RuntimeError(
                "Run Step 3c OCSVM permutation importance first (defines `perm_importance_ocsvm`)."
            ) from e
        col = "importance_mean"
    elif s == "perm_lof":
        try:
            df = perm_importance_lof
        except NameError as e:
            raise RuntimeError(
                "Run Step 3c LOF permutation importance first (defines `perm_importance_lof`)."
            ) from e
        col = "importance_mean"
    else:
        raise ValueError(
            f"Unknown importance source {source!r}; use 'rf', 'perm_iso', 'perm_ocsvm', or 'perm_lof'."
        )
    df = df.sort_values(col, ascending=False, kind="mergesort").reset_index(drop=True)
    pool = df["feature"].astype(str).tolist()
    imp = df.set_index("feature")[col].astype(float).to_dict()
    return pool, imp


def refresh_rfe_pool_globals(source: Optional[str] = None) -> None:
    """Rebuild `RFE_POOL_ORDERED` after changing `RFE_IMPORTANCE_SOURCE` or rerunning Step 3c/3."""
    global RFE_POOL_ORDERED, RFE_IMPORTANCE_MAP, _RFE_POOL_INDEX, FEATURE_POOL_RF_ORDERED
    src = RFE_IMPORTANCE_SOURCE if source is None else source
    RFE_POOL_ORDERED, RFE_IMPORTANCE_MAP = build_rfe_pool_from_source(src)
    _RFE_POOL_INDEX = {f: i for i, f in enumerate(RFE_POOL_ORDERED)}
    FEATURE_POOL_RF_ORDERED = RFE_POOL_ORDERED


refresh_rfe_pool_globals()

# Full cohort (same as client_data in models.py); do not restrict to X_use finite-only rows.
person_eval = person_data_raw.copy()
y_fraud_eval = person_eval["is_fraud"].astype(int).values
train_mask_eval = ~person_eval["is_fraud"].astype(bool).values
train_data_eval = person_eval.loc[train_mask_eval]

# Stop when this many features remain (1 = eliminate one feature per step down to a single column).
N_FEATURES_RFE_TARGET = 1

AnomalyModelKey = Literal["iso", "ocsvm", "lof"]


def _scores_iso(X_fit: np.ndarray, X_eval: np.ndarray) -> np.ndarray:
    iso = IsolationForest(
        n_estimators=200,
        contamination=0.0005,
        max_samples=1.0,
        random_state=RANDOM_STATE,
        n_jobs=-1,
    )
    iso.fit(X_fit)
    return -iso.score_samples(X_eval)


def _scores_ocsvm(X_fit: np.ndarray, X_eval: np.ndarray) -> np.ndarray:
    n_fit = len(X_fit)
    if n_fit > MAX_OCSVM_TRAIN:
        rng = np.random.default_rng(42)
        idx = rng.choice(n_fit, size=MAX_OCSVM_TRAIN, replace=False)
        X_fit_s = X_fit[idx]
    else:
        X_fit_s = X_fit
    ocsvm = OneClassSVM(kernel="rbf", nu=0.0005, gamma="scale")
    ocsvm.fit(X_fit_s)
    return -ocsvm.decision_function(X_eval)


def _scores_lof(X_fit: np.ndarray, X_eval: np.ndarray) -> np.ndarray:
    lof = LocalOutlierFactor(
        n_neighbors=5,
        contamination=0.01,
        metric="minkowski",
        p=2,
        novelty=True,
    )
    lof.fit(X_fit)
    return -lof.score_samples(X_eval)


_SCORERS = {
    "iso": _scores_iso,
    "ocsvm": _scores_ocsvm,
    "lof": _scores_lof,
}


def _evaluate_feature_pool_metrics(
    feature_names: list[str], model_key: AnomalyModelKey
) -> tuple[float, float]:
    X_fit_df, X_all_df = scale_features(
        data=person_eval,
        features=feature_names,
        scaler_type="standard",
        skew_abs_threshold=SKEW_ABS_THRESHOLD,
        fit_data=train_data_eval,
    )
    X_fit = X_fit_df.values.astype(np.float64)
    X_eval = X_all_df.values.astype(np.float64)
    scores = _SCORERS[model_key](X_fit, X_eval)
    m = _top_k_precision(scores, y_fraud_eval, K_LIST)
    return float(m["precision@50"]), float(m["precision@100"])


def _evaluate_feature_pool(
    feature_names: list[str], model_key: AnomalyModelKey
) -> float:
    p50, _ = _evaluate_feature_pool_metrics(feature_names, model_key)
    return p50


def _removal_acceptable(
    b50: float,
    b100: float,
    a50: float,
    a100: float,
    guard: RFERemovalGuard,
) -> bool:
    if guard == "p50_only":
        return a50 >= b50 - _RFE_METRIC_EPS
    if guard == "p100_only":
        return a100 >= b100 - _RFE_METRIC_EPS
    if guard == "both":
        return a50 >= b50 - _RFE_METRIC_EPS and a100 >= b100 - _RFE_METRIC_EPS
    # p50_primary: optimize @50; on tie, @100 must not decrease
    if a50 < b50 - _RFE_METRIC_EPS:
        return False
    if a50 > b50 + _RFE_METRIC_EPS:
        return True
    return a100 >= b100 - _RFE_METRIC_EPS


def _rfe_guard_summary(guard: RFERemovalGuard) -> str:
    if guard == "p50_primary":
        return "skip if precision@50 falls, or ties @50 with a drop in precision@100"
    if guard == "p50_only":
        return "skip only if precision@50 would fall (precision@100 may change freely)"
    if guard == "p100_only":
        return "skip only if precision@100 would fall (precision@50 may change freely)"
    return "skip if either precision@50 or precision@100 would fall"


def _print_rfe_step(
    step,
    n_feat: int,
    p50: float,
    removed: Optional[str] = None,
    p50_before: Optional[float] = None,
    drop50: Optional[float] = None,
    p100: Optional[float] = None,
    p100_before: Optional[float] = None,
    drop100: Optional[float] = None,
):
    label = str(step) if isinstance(step, str) else str(int(step))
    parts = [f"step {label:>5}", f"n_features={n_feat:4d}", f"precision@50={p50:.4f}"]
    if p100 is not None:
        parts.append(f"precision@100={p100:.4f}")
    if p50_before is not None:
        parts.append(f"prec50_before={p50_before:.4f}")
    if p100_before is not None:
        parts.append(f"prec100_before={p100_before:.4f}")
    if drop50 is not None:
        parts.append(f"drop50={drop50:.4f}")
    if drop100 is not None:
        parts.append(f"drop100={drop100:.4f}")
    if removed:
        parts.append(f"removed={removed}")
    print(" | ".join(parts))


def backward_rfe_anomaly(
    feature_names: list[str],
    n_features_to_select: int,
    model_key: AnomalyModelKey,
    *,
    importance_source: Optional[str] = None,
    removal_guard: Optional[RFERemovalGuard] = None,
) -> tuple[list[str], pd.DataFrame]:
    src = RFE_IMPORTANCE_SOURCE if importance_source is None else importance_source
    rg = RFE_REMOVAL_GUARD if removal_guard is None else removal_guard
    if rg not in ("p50_primary", "p50_only", "p100_only", "both"):
        raise ValueError(
            f"Unknown removal_guard {rg!r}; use 'p50_primary', 'p50_only', 'p100_only', or 'both'."
        )
    pool_ord, imp_map = build_rfe_pool_from_source(src)
    pool_index = {f: i for i, f in enumerate(pool_ord)}
    pool_set = set(pool_ord)
    fn_set = set(feature_names)

    if pool_set == fn_set:
        working = list(pool_ord)
    elif pool_set < fn_set:
        if not pool_set <= fn_set:
            raise ValueError(
                f"importance pool for {src!r} is not a subset of feature_names. "
                f"symmetric difference: {pool_set.symmetric_difference(fn_set)}"
            )
        print(
            f"RFE: importance table lists {len(pool_set)} features (subset of {len(fn_set)} passed names); using the table set."
        )
        working = list(pool_ord)
    elif fn_set < pool_set:
        working = [f for f in pool_ord if f in fn_set]
        if set(working) != fn_set:
            raise ValueError(
                f"feature_names must equal the subset of importance-ordered features. "
                f"symmetric difference: {set(working).symmetric_difference(fn_set)}"
            )
    else:
        raise ValueError(
            f"feature_names and importance pool for {src!r} do not align. "
            f"Either use the same set, or pass a superset when the table is a filtered subset (e.g. Step 3c). "
            f"symmetric difference: {pool_set.symmetric_difference(fn_set)}"
        )

    if n_features_to_select < 1 or n_features_to_select > len(working):
        raise ValueError("n_features_to_select must be between 1 and len(working)")

    print(
        f"\n--- RFE model={model_key} | pool n={len(working)} | importance_source={src!r} | "
        f"removal_guard={rg!r} | try removals in ascending importance (lowest first); "
        f"{_rfe_guard_summary(rg)} ---"
    )
    rows = []
    step = 0
    b50, b100 = _evaluate_feature_pool_metrics(working, model_key)
    rows.append(
        {
            "step": step,
            "action": "start",
            "removed": None,
            "n_features": len(working),
            "precision@100": b100,
            "precision@50": b50,
            "importance_source": src,
            "removal_guard": rg,
            "features": ", ".join(working),
        }
    )
    _print_rfe_step(step, len(working), b50, p100=b100)

    while len(working) > n_features_to_select:
        step += 1
        b50, b100 = _evaluate_feature_pool_metrics(working, model_key)
        candidates = sorted(
            working,
            key=lambda f: (imp_map[f], -pool_index[f]),
        )
        removed = None
        best50 = b50
        best100 = b100
        imp_removed: Optional[float] = None
        for cand in candidates:
            trial = [f for f in working if f != cand]
            a50, a100 = _evaluate_feature_pool_metrics(trial, model_key)
            if _removal_acceptable(b50, b100, a50, a100, rg):
                removed = cand
                best50, best100 = a50, a100
                imp_removed = float(imp_map[cand])
                break
        if removed is None:
            print(
                f"RFE: no safe removal under guard={rg!r} — {_rfe_guard_summary(rg)}; "
                f"stopping with n_features={len(working)} (precision@50={b50:.4f}, precision@100={b100:.4f})."
            )
            rows.append(
                {
                    "step": step,
                    "action": "stop_performance_guard",
                    "removed": None,
                    "n_features": len(working),
                    "precision@100": b100,
                    "precision@50": b50,
                    "precision@100_before": b100,
                    "precision@50_before": b50,
                    "importance_source": src,
                    "removal_guard": rg,
                    "features": ", ".join(working),
                }
            )
            break
        working.remove(removed)
        drop50 = b50 - best50
        drop100 = b100 - best100
        rows.append(
            {
                "step": step,
                "action": "remove_by_importance_if_safe",
                "removed": removed,
                "importance_at_removal": imp_removed,
                "rf_mdi_removed": imp_removed,
                "n_features": len(working),
                "precision@100": best100,
                "precision@50": best50,
                "precision@100_before": b100,
                "precision@50_before": b50,
                "drop_in_precision@100": drop100,
                "drop_in_precision@50": drop50,
                "importance_source": src,
                "removal_guard": rg,
                "features": ", ".join(working),
            }
        )
        _print_rfe_step(
            step,
            len(working),
            best50,
            removed=removed,
            p50_before=b50,
            drop50=drop50,
            p100=best100,
            p100_before=b100,
            drop100=drop100,
        )

    final50, final100 = _evaluate_feature_pool_metrics(working, model_key)
    rows.append(
        {
            "step": step + 1,
            "action": "final",
            "removed": None,
            "n_features": len(working),
            "precision@100": final100,
            "precision@50": final50,
            "importance_source": src,
            "removal_guard": rg,
            "features": ", ".join(working),
        }
    )
    _print_rfe_step("final", len(working), final50, p100=final100)
    return working, pd.DataFrame(rows)


print(
    f"Step 4a: RFE_IMPORTANCE_SOURCE={RFE_IMPORTANCE_SOURCE!r} | "
    f"RFE_REMOVAL_GUARD={RFE_REMOVAL_GUARD!r} | "
    f"RFE_POOL_ORDERED n={len(RFE_POOL_ORDERED)}; person_eval rows={len(person_eval)}; "
    f"RFE target n_features={N_FEATURES_RFE_TARGET} "
    f"({_rfe_guard_summary(RFE_REMOVAL_GUARD)}; else early stop)"
)
# Out:
# Step 4a: RFE_IMPORTANCE_SOURCE='rf' | RFE_REMOVAL_GUARD='p50_primary' | RFE_POOL_ORDERED n=31; person_eval rows=197763; RFE target n_features=1 (skip if precision@50 falls, or ties @50 with a drop in precision@100; else early stop)

# %% [markdown]
# ### Step 4b — Isolation Forest
#
# Same **importance-driven** removal order as Step 4a; **`precision@50`** primary ( **`precision@100`** tie-break) from Isolation Forest.

# %%
# Uses `RFE_IMPORTANCE_SOURCE` from Step 4a, unless you pass `importance_source=`.
rfe_selected_iso, rfe_history_iso = backward_rfe_anomaly(
    RFE_POOL_ORDERED,
    N_FEATURES_RFE_TARGET,
    "iso",
    importance_source="perm_iso",
)
display(rfe_history_iso)
best_iso_features = rfe_history_iso.sort_values("precision@50", ascending=False)["features"].values[0]
display(best_iso_features)

print("\nIsolation Forest — selected features:")
for j, name in enumerate(rfe_selected_iso, 1):
    print(f"  {j:2d}. {name}")
_fp50, _fp100 = _evaluate_feature_pool_metrics(rfe_selected_iso, "iso")
print(f"\nFinal precision@50: {_fp50:.4f} | precision@100: {_fp100:.4f}")
# Out:
# RFE: importance table lists 24 features (subset of 31 passed names); using the table set.
#
# --- RFE model=iso | pool n=24 | importance_source='perm_iso' | try removals in ascending importance (lowest first); skip if precision@100 falls, or ties with a drop in precision@50 ---
# step     0 | n_features=  24 | precision@100=0.1300 | precision@50=0.0800
# step     1 | n_features=  23 | precision@100=0.1700 | precision@50=0.1400 | prec100_before=0.1300 | prec50_before=0.0800 | drop100=-0.0400 | drop50=-0.0600 | removed=gross_amount_max
# step     2 | n_features=  22 | precision@100=0.1900 | precision@50=0.2800 | prec100_before=0.1700 | prec50_before=0.1400 | drop100=-0.0200 | drop50=-0.1400 | removed=num_of_trn
# step     3 | n_features=  21 | precision@100=0.2100 | precision@50=0.2400 | prec100_before=0.1900 | prec50_before=0.2800 | drop100=-0.0200 | drop50=0.0400 | removed=gross_amount_mean
# step     4 | n_features=  20 | precision@100=0.2200 | precision@50=0.2200 | prec100_before=0.2100 | prec50_before=0.2400 | drop100=-0.0100 | drop50=0.0200 | removed=first_second_trn_diff_prcnt
# RFE: no safe removal — every candidate worsens precision@100 or ties @100 with lower @50; stopping with n_features=20 (precision@100=0.2200, precision@50=0.2200).
# step final | n_features=  20 | precision@100=0.2200 | precision@50=0.2200
#    step                        action                      removed  \
# 0     0                         start                         None
# 1     1  remove_by_importance_if_safe             gross_amount_max
# 2     2  remove_by_importance_if_safe                   num_of_trn
# 3     3  remove_by_importance_if_safe            gross_amount_mean
# 4     4  remove_by_importance_if_safe  first_second_trn_diff_prcnt
# 5     5        stop_performance_guard                         None
# 6     6                         final                         None
#
#    n_features  precision@100  precision@50 importance_source  \
# 0          24           0.13          0.08          perm_iso
# 1          23           0.17          0.14          perm_iso
# 2          22           0.19          0.28          perm_iso
# 3          21           0.21          0.24          perm_iso
# 4          20           0.22          0.22          perm_iso
# 5          20           0.22          0.22          perm_iso
# 6          20           0.22          0.22          perm_iso
#
#                                             features  importance_at_removal  \
# 0  share_top_waiter, num_of_waiters, gross_amount...                    NaN
# 1  share_top_waiter, num_of_waiters, gross_amount...                 -0.020
# 2  share_top_waiter, num_of_waiters, gross_amount...                 -0.004
# 3  share_top_waiter, num_of_waiters, gross_amount...                 -0.002
# 4  share_top_waiter, num_of_waiters, gross_amount...                  0.008
# 5  share_top_waiter, num_of_waiters, gross_amount...                    NaN
# 6  share_top_waiter, num_of_waiters, gross_amount...                    NaN
#
#    rf_mdi_removed  precision@100_before  precision@50_before  \
# 0             NaN                   NaN                  NaN
# 1          -0.020                  0.13                 0.08
# 2          -0.004                  0.17                 0.14
# 3          -0.002                  0.19                 0.28
# 4           0.008                  0.21                 0.24
# 5             NaN                  0.22                 0.22
# 6             NaN                   NaN                  NaN
#
#    drop_in_precision@100  drop_in_precision@50
# 0                    NaN                   NaN
# 1                  -0.04                 -0.06
# 2                  -0.02                 -0.14
# 3                  -0.02                  0.04
# 4                  -0.01                  0.02
# 5                    NaN                   NaN
# 6                    NaN                   NaN
# 'share_top_waiter, num_of_waiters, gross_amount_mean_prcnt, num_of_trn_prcnt, bonuses_used_sum_prcnt, bonuses_accum_sum_prcnt, first_last_trn_diff_prcnt, share_top_places, share_bonuses_used_top_waiter, bonuses_used_sum, trn_per_day, bonuses_accum_sum, num_of_places_prcnt, time_between_trn_median, gross_amount_max_prcnt, bonus_trn_count, first_third_trn_diff, time_between_trn_median_prcnt, first_third_trn_diff_prcnt, first_second_trn_diff'
# Isolation Forest — selected features:
#    1. share_top_waiter
#    2. num_of_waiters
#    3. gross_amount_mean_prcnt
#    4. num_of_trn_prcnt
#    5. bonuses_used_sum_prcnt
#    6. bonuses_accum_sum_prcnt
#    7. first_last_trn_diff_prcnt
#    8. share_top_places
#    9. share_bonuses_used_top_waiter
#   10. bonuses_used_sum
#   11. trn_per_day
#   12. bonuses_accum_sum
#   13. num_of_places_prcnt
#   14. time_between_trn_median
#   15. gross_amount_max_prcnt
#   16. bonus_trn_count
#   17. first_third_trn_diff
#   18. time_between_trn_median_prcnt
#   19. first_third_trn_diff_prcnt
#   20. first_second_trn_diff
#
# Final precision@100: 0.2200 | precision@50: 0.2200

# %% [markdown]
# ### Step 4c — One-Class SVM
#
# Same **importance-driven** removal order; **`precision@50`** primary (**`precision@100`** tie-break) from OCSVM (subsample if **`MAX_OCSVM_TRAIN`** exceeded).

# %% [markdown]
# Optional: for **OCSVM** RFE below, uncomment `importance_source="perm_ocsvm"` to order removals by Step 3c permutation **`importance_mean`** instead of `RFE_IMPORTANCE_SOURCE`.

# %%
rfe_selected_ocsvm, rfe_history_ocsvm = backward_rfe_anomaly(
    RFE_POOL_ORDERED,
    N_FEATURES_RFE_TARGET,
    "ocsvm",
    # importance_source="perm_ocsvm",
    removal_guard="p100_only"
)
display(rfe_history_ocsvm)
best_ocsvm_features = rfe_history_ocsvm.sort_values("precision@50", ascending=False)["features"].values[0]
display(best_ocsvm_features)

print("\nOne-Class SVM — selected features:")
for j, name in enumerate(rfe_selected_ocsvm, 1):
    print(f"  {j:2d}. {name}")
_fp50, _fp100 = _evaluate_feature_pool_metrics(rfe_selected_ocsvm, "ocsvm")
print(f"\nFinal precision@50: {_fp50:.4f} | precision@100: {_fp100:.4f}")
# Out:
# --- RFE model=ocsvm | pool n=31 | importance_source='rf' | removal_guard='p100_only' | try removals in ascending importance (lowest first); skip only if precision@100 would fall (precision@50 may change freely) ---
# step     0 | n_features=  31 | precision@50=0.1200 | precision@100=0.0800
# step     1 | n_features=  30 | precision@50=0.1000 | precision@100=0.0800 | prec50_before=0.1200 | prec100_before=0.0800 | drop50=0.0200 | drop100=0.0000 | removed=bonus_trn_count
# step     2 | n_features=  29 | precision@50=0.1000 | precision@100=0.1000 | prec50_before=0.1000 | prec100_before=0.0800 | drop50=0.0000 | drop100=-0.0200 | removed=gross_amount_mean
# step     3 | n_features=  28 | precision@50=0.1000 | precision@100=0.1000 | prec50_before=0.1000 | prec100_before=0.1000 | drop50=0.0000 | drop100=0.0000 | removed=first_third_trn_diff
# step     4 | n_features=  27 | precision@50=0.1000 | precision@100=0.1000 | prec50_before=0.1000 | prec100_before=0.1000 | drop50=0.0000 | drop100=0.0000 | removed=days_visits
# step     5 | n_features=  26 | precision@50=0.1000 | precision@100=0.1000 | prec50_before=0.1000 | prec100_before=0.1000 | drop50=0.0000 | drop100=0.0000 | removed=first_last_trn_diff
# step     6 | n_features=  25 | precision@50=0.0600 | precision@100=0.1200 | prec50_before=0.1000 | prec100_before=0.1000 | drop50=0.0400 | drop100=-0.0200 | removed=trn_per_day
# step     7 | n_features=  24 | precision@50=0.1000 | precision@100=0.1400 | prec50_before=0.0600 | prec100_before=0.1200 | drop50=-0.0400 | drop100=-0.0200 | removed=gross_amount_max
# step     8 | n_features=  23 | precision@50=0.0800 | precision@100=0.1400 | prec50_before=0.1000 | prec100_before=0.1400 | drop50=0.0200 | drop100=0.0000 | removed=time_between_trn_median
# step     9 | n_features=  22 | precision@50=0.1000 | precision@100=0.1400 | prec50_before=0.0800 | prec100_before=0.1400 | drop50=-0.0200 | drop100=0.0000 | removed=first_third_trn_diff_prcnt
# step    10 | n_features=  21 | precision@50=0.0800 | precision@100=0.1400 | prec50_before=0.1000 | prec100_before=0.1400 | drop50=0.0200 | drop100=0.0000 | removed=gross_amount_mean_prcnt
# step    11 | n_features=  20 | precision@50=0.0600 | precision@100=0.1400 | prec50_before=0.0800 | prec100_before=0.1400 | drop50=0.0200 | drop100=0.0000 | removed=first_second_trn_diff_prcnt
# step    12 | n_features=  19 | precision@50=0.0600 | precision@100=0.1400 | prec50_before=0.0600 | prec100_before=0.1400 | drop50=0.0000 | drop100=0.0000 | removed=num_of_places
# step    13 | n_features=  18 | precision@50=0.0800 | precision@100=0.1400 | prec50_before=0.0600 | prec100_before=0.1400 | drop50=-0.0200 | drop100=0.0000 | removed=days_visits_prcnt
# step    14 | n_features=  17 | precision@50=0.1400 | precision@100=0.1500 | prec50_before=0.0800 | prec100_before=0.1400 | drop50=-0.0600 | drop100=-0.0100 | removed=num_of_trn
# step    15 | n_features=  16 | precision@50=0.1200 | precision@100=0.1500 | prec50_before=0.1400 | prec100_before=0.1500 | drop50=0.0200 | drop100=0.0000 | removed=num_of_places_prcnt
# step    16 | n_features=  15 | precision@50=0.1400 | precision@100=0.1500 | prec50_before=0.1200 | prec100_before=0.1500 | drop50=-0.0200 | drop100=0.0000 | removed=first_last_trn_diff_prcnt
# step    17 | n_features=  14 | precision@50=0.1800 | precision@100=0.1500 | prec50_before=0.1400 | prec100_before=0.1500 | drop50=-0.0400 | drop100=0.0000 | removed=gross_amount_max_prcnt
# step    18 | n_features=  13 | precision@50=0.1800 | precision@100=0.1600 | prec50_before=0.1800 | prec100_before=0.1500 | drop50=0.0000 | drop100=-0.0100 | removed=first_second_trn_diff
# step    19 | n_features=  12 | precision@50=0.2200 | precision@100=0.1800 | prec50_before=0.1800 | prec100_before=0.1600 | drop50=-0.0400 | drop100=-0.0200 | removed=bonuses_used_sum_prcnt
# step    20 | n_features=  11 | precision@50=0.2200 | precision@100=0.1800 | prec50_before=0.2200 | prec100_before=0.1800 | drop50=0.0000 | drop100=0.0000 | removed=share_top_places
# step    21 | n_features=  10 | precision@50=0.2000 | precision@100=0.1800 | prec50_before=0.2200 | prec100_before=0.1800 | drop50=0.0200 | drop100=0.0000 | removed=num_of_trn_prcnt
# step    22 | n_features=   9 | precision@50=0.2800 | precision@100=0.1900 | prec50_before=0.2000 | prec100_before=0.1800 | drop50=-0.0800 | drop100=-0.0100 | removed=gross_amount_sum
# step    23 | n_features=   8 | precision@50=0.3200 | precision@100=0.2000 | prec50_before=0.2800 | prec100_before=0.1900 | drop50=-0.0400 | drop100=-0.0100 | removed=bonuses_used_sum
# step    24 | n_features=   7 | precision@50=0.3200 | precision@100=0.2000 | prec50_before=0.3200 | prec100_before=0.2000 | drop50=0.0000 | drop100=0.0000 | removed=time_between_trn_median_prcnt
# step    25 | n_features=   6 | precision@50=0.3200 | precision@100=0.2000 | prec50_before=0.3200 | prec100_before=0.2000 | drop50=0.0000 | drop100=0.0000 | removed=num_of_waiters
# step    26 | n_features=   5 | precision@50=0.3000 | precision@100=0.2200 | prec50_before=0.3200 | prec100_before=0.2000 | drop50=0.0200 | drop100=-0.0200 | removed=gross_amount_sum_prcnt
# RFE: no safe removal under guard='p100_only' — skip only if precision@100 would fall (precision@50 may change freely); stopping with n_features=5 (precision@50=0.3000, precision@100=0.2200).
# step final | n_features=   5 | precision@50=0.3000 | precision@100=0.2200
#     step                        action                        removed  \
# 0      0                         start                           None
# 1      1  remove_by_importance_if_safe                bonus_trn_count
# 2      2  remove_by_importance_if_safe              gross_amount_mean
# 3      3  remove_by_importance_if_safe           first_third_trn_diff
# 4      4  remove_by_importance_if_safe                    days_visits
# 5      5  remove_by_importance_if_safe            first_last_trn_diff
# 6      6  remove_by_importance_if_safe                    trn_per_day
# 7      7  remove_by_importance_if_safe               gross_amount_max
# 8      8  remove_by_importance_if_safe        time_between_trn_median
# 9      9  remove_by_importance_if_safe     first_third_trn_diff_prcnt
# 10    10  remove_by_importance_if_safe        gross_amount_mean_prcnt
# 11    11  remove_by_importance_if_safe    first_second_trn_diff_prcnt
# 12    12  remove_by_importance_if_safe                  num_of_places
# 13    13  remove_by_importance_if_safe              days_visits_prcnt
# 14    14  remove_by_importance_if_safe                     num_of_trn
# 15    15  remove_by_importance_if_safe            num_of_places_prcnt
# 16    16  remove_by_importance_if_safe      first_last_trn_diff_prcnt
# 17    17  remove_by_importance_if_safe         gross_amount_max_prcnt
# 18    18  remove_by_importance_if_safe          first_second_trn_diff
# 19    19  remove_by_importance_if_safe         bonuses_used_sum_prcnt
# 20    20  remove_by_importance_if_safe               share_top_places
# 21    21  remove_by_importance_if_safe               num_of_trn_prcnt
# 22    22  remove_by_importance_if_safe               gross_amount_sum
# 23    23  remove_by_importance_if_safe               bonuses_used_sum
# 24    24  remove_by_importance_if_safe  time_between_trn_median_prcnt
# 25    25  remove_by_importance_if_safe                 num_of_waiters
# 26    26  remove_by_importance_if_safe         gross_amount_sum_prcnt
# 27    27        stop_performance_guard                           None
# 28    28                         final                           None
#
#     n_features  precision@100  precision@50 importance_source removal_guard  \
# 0           31           0.08          0.12                rf     p100_only
# 1           30           0.08          0.10                rf     p100_only
# 2           29           0.10          0.10                rf     p100_only
# 3           28           0.10          0.10                rf     p100_only
# 4           27           0.10          0.10                rf     p100_only
# 5           26           0.10          0.10                rf     p100_only
# 6           25           0.12          0.06                rf     p100_only
# 7           24           0.14          0.10                rf     p100_only
# 8           23           0.14          0.08                rf     p100_only
# 9           22           0.14          0.10                rf     p100_only
# 10          21           0.14          0.08                rf     p100_only
# 11          20           0.14          0.06                rf     p100_only
# 12          19           0.14          0.06                rf     p100_only
# 13          18           0.14          0.08                rf     p100_only
# 14          17           0.15          0.14                rf     p100_only
# 15          16           0.15          0.12                rf     p100_only
# 16          15           0.15          0.14                rf     p100_only
# 17          14           0.15          0.18                rf     p100_only
# 18          13           0.16          0.18                rf     p100_only
# 19          12           0.18          0.22                rf     p100_only
# 20          11           0.18          0.22                rf     p100_only
# 21          10           0.18          0.20                rf     p100_only
# 22           9           0.19          0.28                rf     p100_only
# 23           8           0.20          0.32                rf     p100_only
# 24           7           0.20          0.32                rf     p100_only
# 25           6           0.20          0.32                rf     p100_only
# 26           5           0.22          0.30                rf     p100_only
# 27           5           0.22          0.30                rf     p100_only
# 28           5           0.22          0.30                rf     p100_only
#
#                                              features  importance_at_removal  \
# 0   share_top_waiter, bonuses_accum_sum, bonuses_a...                    NaN
# 1   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.002278
# 2   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.003318
# 3   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.004798
# 4   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.005453
# 5   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.005231
# 6   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.005772
# 7   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.010681
# 8   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.006510
# 9   share_top_waiter, bonuses_accum_sum, bonuses_a...               0.008506
# 10  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.007402
# 11  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.008549
# 12  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.008953
# 13  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.010211
# 14  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.012046
# 15  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.011904
# 16  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.017172
# 17  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.034019
# 18  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.009215
# 19  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.041871
# 20  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.057851
# 21  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.023817
# 22  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.071993
# 23  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.079568
# 24  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.011177
# 25  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.030451
# 26  share_top_waiter, bonuses_accum_sum, bonuses_a...               0.059484
# 27  share_top_waiter, bonuses_accum_sum, bonuses_a...                    NaN
# 28  share_top_waiter, bonuses_accum_sum, bonuses_a...                    NaN
#
#     rf_mdi_removed  precision@100_before  precision@50_before  \
# 0              NaN                   NaN                  NaN
# 1         0.002278                  0.08                 0.12
# 2         0.003318                  0.08                 0.10
# 3         0.004798                  0.10                 0.10
# 4         0.005453                  0.10                 0.10
# 5         0.005231                  0.10                 0.10
# 6         0.005772                  0.10                 0.10
# 7         0.010681                  0.12                 0.06
# 8         0.006510                  0.14                 0.10
# 9         0.008506                  0.14                 0.08
# 10        0.007402                  0.14                 0.10
# 11        0.008549                  0.14                 0.08
# 12        0.008953                  0.14                 0.06
# 13        0.010211                  0.14                 0.06
# 14        0.012046                  0.14                 0.08
# 15        0.011904                  0.15                 0.14
# 16        0.017172                  0.15                 0.12
# 17        0.034019                  0.15                 0.14
# 18        0.009215                  0.15                 0.18
# 19        0.041871                  0.16                 0.18
# 20        0.057851                  0.18                 0.22
# 21        0.023817                  0.18                 0.22
# 22        0.071993                  0.18                 0.20
# 23        0.079568                  0.19                 0.28
# 24        0.011177                  0.20                 0.32
# 25        0.030451                  0.20                 0.32
# 26        0.059484                  0.20                 0.32
# 27             NaN                  0.22                 0.30
# 28             NaN                   NaN                  NaN
#
#     drop_in_precision@100  drop_in_precision@50
# 0                     NaN                   NaN
# 1                    0.00                  0.02
# 2                   -0.02                  0.00
# 3                    0.00                  0.00
# 4                    0.00                  0.00
# 5                    0.00                  0.00
# 6                   -0.02                  0.04
# 7                   -0.02                 -0.04
# 8                    0.00                  0.02
# 9                    0.00                 -0.02
# 10                   0.00                  0.02
# 11                   0.00                  0.02
# 12                   0.00                  0.00
# 13                   0.00                 -0.02
# 14                  -0.01                 -0.06
# 15                   0.00                  0.02
# 16                   0.00                 -0.02
# 17                   0.00                 -0.04
# 18                  -0.01                  0.00
# 19                  -0.02                 -0.04
# 20                   0.00                  0.00
# 21                   0.00                  0.02
# 22                  -0.01                 -0.08
# 23                  -0.01                 -0.04
# 24                   0.00                  0.00
# 25                   0.00                  0.00
# 26                  -0.02                  0.02
# 27                    NaN                   NaN
# 28                    NaN                   NaN
# 'share_top_waiter, bonuses_accum_sum, bonuses_accum_sum_prcnt, gross_amount_sum_prcnt, share_bonuses_used_top_waiter, num_of_waiters_prcnt'
# One-Class SVM — selected features:
#    1. share_top_waiter
#    2. bonuses_accum_sum
#    3. bonuses_accum_sum_prcnt
#    4. share_bonuses_used_top_waiter
#    5. num_of_waiters_prcnt
#
# Final precision@50: 0.3000 | precision@100: 0.2200

# %% [markdown]
# Final precision@50: 0.3200 | precision@100: 0.2000 for both
# Final precision@50: 0.3000 | precision@100: 0.2200 for p100_only

# %% [markdown]
# ### Step 4d — Local Outlier Factor (LOF)
#
# Same **importance-driven** removal order; **`precision@50`** primary (**`precision@100`** tie-break) from **`novelty=True`** LOF.

# %% [markdown]
# Optional: uncomment `importance_source="perm_lof"` in the LOF cell for permutation-based removal order.

# %%
rfe_selected_lof, rfe_history_lof = backward_rfe_anomaly(
    RFE_POOL_ORDERED,
    N_FEATURES_RFE_TARGET,
    "lof",
    # importance_source="perm_lof",
)
display(rfe_history_lof)

print("\nLOF — selected features:")
for j, name in enumerate(rfe_selected_lof, 1):
    print(f"  {j:2d}. {name}")
_fp50, _fp100 = _evaluate_feature_pool_metrics(rfe_selected_lof, "lof")
print(f"\nFinal precision@50: {_fp50:.4f} | precision@100: {_fp100:.4f}")
# Out:
# --- RFE model=lof | pool n=31 | elimination order = lowest RF MDI first ---
# step     0 | n_features=  31 | precision@100=0.0100
# step     1 | n_features=  30 | precision@100=0.0100 | prec_before=0.0100 | drop=0.0000 | removed=bonus_trn_count
# step     2 | n_features=  29 | precision@100=0.0000 | prec_before=0.0100 | drop=0.0100 | removed=gross_amount_mean
